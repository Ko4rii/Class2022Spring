# %% [markdown]
# <a href="https://colab.research.google.com/github/Ko4rii/Class2022Spring/blob/main/image%20processing%20practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pylab as plt

# %%
import os
url = "https://raw.githubusercontent.com/Ko4rii/Class2022Spring/main/lupy.jpg"
os.system("curl " + url + " > test.jpg")
# Out:
# 0

# %%
image_bgr = cv2.imread('test.jpg')
cv2_imshow(image_bgr)
# Out:
# <PIL.Image.Image image mode=RGB size=960x841 at 0x7EFBEB5FF810>

# %%
print(type(image_bgr))
print(image_bgr.shape)
# Out:
# <class 'numpy.ndarray'>
# (841, 960, 3)

# %%
image_b = image_bgr.copy()
image_b[:,:,[1,2]]=0
cv2_imshow(image_b)
# Out:
# <PIL.Image.Image image mode=RGB size=960x841 at 0x7EFBEB5A4FD0>

# %%
image_inverse=255-image_b
cv2_imshow(image_inverse)
# Out:
# <PIL.Image.Image image mode=RGB size=960x841 at 0x7EFBE1323A90>
